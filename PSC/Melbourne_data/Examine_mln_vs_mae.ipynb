# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
dt = pd.read_csv('mln_vs_mae.csv')

# %%
del dt['id']

# %%
dt.head()
# Out:
#    max_leaf_node            mae
# 0              2  439583.613472
# 1              3  418485.103926
# 2              4  388538.893705
# 3              5  385696.542789
# 4              6  365825.654185

# %%
dt.describe()
# Out:
#        max_leaf_node            mae
# count    4998.000000    4998.000000
# mean     2500.500000  269372.239302
# std      1442.942653    6947.448252
# min         2.000000  259946.138351
# 25%      1251.250000  265899.062795
# 50%      2500.500000  271269.075381
# 75%      3749.750000  271986.564181
# max      4999.000000  439583.613472

# %%
dt['mae'].min()
# Out:
# 259946.13835124

# %%
dt.loc[dt['mae'].idxmin()]
# Out:
# max_leaf_node       791.000000
# mae              259946.138351
# Name: 789, dtype: float64

# %%
dt['mae'].mean()
# Out:
# 269372.23930177244

# %%
fig = plt.figure(figsize=(16,9),dpi=300)
plt.plot(dt['max_leaf_node'],dt['mae'])
plt.scatter([791],[259946.138351] , color = 'red',label='minimum')
plt.axhline(269372.23930177244,color='red',label='Minimum MAE',linewidth = 1)
# plt.axvline(791,color='green',label='Maximum leaf node with minimum MAE',linewidth=1)
plt.tight_layout()
plt.legend()
plt.show()
